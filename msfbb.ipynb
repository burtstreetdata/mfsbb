# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json

# %%
with open("c:/tmp/pbp.json", 'r') as f :
    game = json.load(f)

# %%
game
# Out:
# {'lastUpdatedOn': '2018-11-17T23:34:25.893Z',
#  'game': {'id': 44792,
#   'startTime': '2018-07-10T23:05:00.000Z',
#   'endedTime': None,
#   'awayTeam': {'id': 114, 'abbreviation': 'NYY'},
#   'homeTeam': {'id': 111, 'abbreviation': 'BAL'},
#   'venue': {'id': 123, 'name': 'Oriole Park at Camden Yards'},
#   'venueAllegiance': 'HOME',
#   'scheduleStatus': 'NORMAL',
#   'originalStartTime': None,
#   'delayedOrPostponedReason': None,
#   'playedStatus': 'COMPLETED',
#   'attendance': None,
#   'officials': [],
#   'broadcasters': [],
#   'weather': None},
#  'atBats': [{'inning': 1,
#    'inningHalf': 'TOP',
#    'battingTeam': {'id': 114, 'abbreviation': 'NYY'},
#    'atBatPlay': [{'description': None,
#      'batterUp': {'battingPlayer': {'id': 11091,
#        'firstName': 'Brett',
#        'lastName': 'Gardner',
#        'position': 'LF',
#        'jerseyNumber': 11},
#       'standingLeftOrRight': 'L',
#       'result': 'FLYOUT'},
#      'playStatus': {'batter': {'id': 11091,
#        'firstName': 'Brett',
#        'lastName': 'Gardner',
#        'position': 'LF',
#        'jerseyNumber': 11},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 0,
#       'strikeCount': 0,
#       'outCount': 0}},
#     {'description': None,
#      'pitch': {'battingPlayer': {'id': 11091,
#        'firstName': 'Brett',
#        'lastName': 'Gardner',
#        'position': 'LF',
#        'jerseyNumber': 11},
#       'pitchingPlayer': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'throwingLeftOrRight': 'R',
#       'result': 'BALL',
#       'ballStartSpeed': 91,
#       'ballEndSpeed': 84,
#       'pitchedLocation': {'x': 162, 'y': 155}},
#      'playStatus': {'batter': {'id': 11091,
#        'firstName': 'Brett',
#        'lastName': 'Gardner',
#        'position': 'LF',
#        'jerseyNumber': 11},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 1,
#       'strikeCount': 0,
#       'outCount': 0}},
#     {'description': None,
#      'pitch': {'battingPlayer': {'id': 11091,
#        'firstName': 'Brett',
#        'lastName': 'Gardner',
#        'position': 'LF',
#        'jerseyNumber': 11},
#       'pitchingPlayer': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'throwingLeftOrRight': 'R',
#       'result': 'IN_PLAY_OUTS',
#       'ballStartSpeed': 90,
#       'ballEndSpeed': 83,
#       'pitchedLocation': {'x': 117, 'y': 174}},
#      'playStatus': {'batter': {'id': 11091,
#        'firstName': 'Brett',
#        'lastName': 'Gardner',
#        'position': 'LF',
#        'jerseyNumber': 11},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 1,
#       'strikeCount': 0,
#       'outCount': 0}},
#     {'description': None,
#      'hit': {'battingPlayer': {'id': 11091,
#        'firstName': 'Brett',
#        'lastName': 'Gardner',
#        'position': 'LF',
#        'jerseyNumber': 11},
#       'pitchingPlayer': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'hitType': 'FLY_BALL',
#       'isOut': True,
#       'isCaughtOut': True,
#       'isError': False,
#       'retrievedByPlayer': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'retrievedAtLocation': {'x': 56, 'y': 112}},
#      'playStatus': {'batter': {'id': 11091,
#        'firstName': 'Brett',
#        'lastName': 'Gardner',
#        'position': 'LF',
#        'jerseyNumber': 11},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 1,
#       'strikeCount': 0,
#       'outCount': 0}},
#     {'description': None,
#      'baseRunAttempt': {'runningPlayer': {'id': 11091,
#        'firstName': 'Brett',
#        'lastName': 'Gardner',
#        'position': 'LF',
#        'jerseyNumber': 11},
#       'fromBase': 0,
#       'toBase': 1,
#       'isSafe': False,
#       'isRunScored': False,
#       'isForcedOut': False,
#       'isWalk': False,
#       'isWalkIntentional': False,
#       'isPassedBall': False,
#       'isWildPitch': False,
#       'isEarnedRun': False},
#      'playStatus': {'batter': {'id': 11091,
#        'firstName': 'Brett',
#        'lastName': 'Gardner',
#        'position': 'LF',
#        'jerseyNumber': 11},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 1,
#       'strikeCount': 0,
#       'outCount': 1}}]},
#   {'inning': 1,
#    'inningHalf': 'TOP',
#    'battingTeam': {'id': 114, 'abbreviation': 'NYY'},
#    'atBatPlay': [{'description': None,
#      'batterUp': {'battingPlayer': {'id': 10734,
#        'firstName': 'Aaron',
#        'lastName': 'Judge',
#        'position': 'RF',
#        'jerseyNumber': 99},
#       'standingLeftOrRight': 'R',
#       'result': 'GROUNDOUT'},
#      'playStatus': {'batter': {'id': 10734,
#        'firstName': 'Aaron',
#        'lastName': 'Judge',
#        'position': 'RF',
#        'jerseyNumber': 99},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 0,
#       'strikeCount': 0,
#       'outCount': 1}},
#     {'description': None,
#      'pitch': {'battingPlayer': {'id': 10734,
#        'firstName': 'Aaron',
#        'lastName': 'Judge',
#        'position': 'RF',
#        'jerseyNumber': 99},
#       'pitchingPlayer': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'throwingLeftOrRight': 'R',
#       'result': 'FOUL',
#       'ballStartSpeed': 91,
#       'ballEndSpeed': 85,
#       'pitchedLocation': {'x': 119, 'y': 172}},
#      'playStatus': {'batter': {'id': 10734,
#        'firstName': 'Aaron',
#        'lastName': 'Judge',
#        'position': 'RF',
#        'jerseyNumber': 99},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 0,
#       'strikeCount': 1,
#       'outCount': 1}},
#     {'description': None,
#      'pitch': {'battingPlayer': {'id': 10734,
#        'firstName': 'Aaron',
#        'lastName': 'Judge',
#        'position': 'RF',
#        'jerseyNumber': 99},
#       'pitchingPlayer': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'throwingLeftOrRight': 'R',
#       'result': 'IN_PLAY_OUTS',
#       'ballStartSpeed': 93,
#       'ballEndSpeed': 85,
#       'pitchedLocation': {'x': 156, 'y': 156}},
#      'playStatus': {'batter': {'id': 10734,
#        'firstName': 'Aaron',
#        'lastName': 'Judge',
#        'position': 'RF',
#        'jerseyNumber': 99},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 0,
#       'strikeCount': 1,
#       'outCount': 1}},
#     {'description': None,
#      'hit': {'battingPlayer': {'id': 10734,
#        'firstName': 'Aaron',
#        'lastName': 'Judge',
#        'position': 'RF',
#        'jerseyNumber': 99},
#       'pitchingPlayer': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'hitType': 'GROUND_BALL',
#       'isOut': True,
#       'isCaughtOut': False,
#       'isError': False,
#       'retrievedByPlayer': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'retrievedAtLocation': {'x': 0, 'y': 0}},
#      'playStatus': {'batter': {'id': 10734,
#        'firstName': 'Aaron',
#        'lastName': 'Judge',
#        'position': 'RF',
#        'jerseyNumber': 99},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 0,
#       'strikeCount': 1,
#       'outCount': 1}},
#     {'description': None,
#      'baseRunAttempt': {'runningPlayer': {'id': 10734,
#        'firstName': 'Aaron',
#        'lastName': 'Judge',
#        'position': 'RF',
#        'jerseyNumber': 99},
#       'fromBase': 0,
#       'toBase': 1,
#       'isSafe': False,
#       'isRunScored': False,
#       'isForcedOut': True,
#       'isWalk': False,
#       'isWalkIntentional': False,
#       'isPassedBall': False,
#       'isWildPitch': False,
#       'isEarnedRun': False},
#      'playStatus': {'batter': {'id': 10734,
#        'firstName': 'Aaron',
#        'lastName': 'Judge',
#        'position': 'RF',
#        'jerseyNumber': 99},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 0,
#       'strikeCount': 1,
#       'outCount': 2}},
#     {'description': None,
#      'ballThrow': {'fromPlayer': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'toPlayer': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'runningPlayer': {'id': 10734,
#        'firstName': 'Aaron',
#        'lastName': 'Judge',
#        'position': 'RF',
#        'jerseyNumber': 99},
#       'fromBase': 1,
#       'toBase': None,
#       'thrownFromLocation': None,
#       'thrownToLocation': None,
#       'isCaught': True,
#       'isRunningPlayerOut': True,
#       'isTagOut': False,
#       'isForceOut': True,
#       'isThrowingError': False,
#       'isCatchingError': False},
#      'playStatus': {'batter': {'id': 10734,
#        'firstName': 'Aaron',
#        'lastName': 'Judge',
#        'position': 'RF',
#        'jerseyNumber': 99},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 0,
#       'strikeCount': 1,
#       'outCount': 2}}]},
#   {'inning': 1,
#    'inningHalf': 'TOP',
#    'battingTeam': {'id': 114, 'abbreviation': 'NYY'},
#    'atBatPlay': [{'description': None,
#      'batterUp': {'battingPlayer': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'standingLeftOrRight': 'L',
#       'result': 'GROUNDOUT'},
#      'playStatus': {'batter': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 0,
#       'strikeCount': 0,
#       'outCount': 2}},
#     {'description': None,
#      'pitch': {'battingPlayer': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'pitchingPlayer': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'throwingLeftOrRight': 'R',
#       'result': 'BALL',
#       'ballStartSpeed': 92,
#       'ballEndSpeed': 84,
#       'pitchedLocation': {'x': 158, 'y': 184}},
#      'playStatus': {'batter': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 1,
#       'strikeCount': 0,
#       'outCount': 2}},
#     {'description': None,
#      'pitch': {'battingPlayer': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'pitchingPlayer': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'throwingLeftOrRight': 'R',
#       'result': 'BALL',
#       'ballStartSpeed': 89,
#       'ballEndSpeed': 82,
#       'pitchedLocation': {'x': 139, 'y': 211}},
#      'playStatus': {'batter': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 2,
#       'strikeCount': 0,
#       'outCount': 2}},
#     {'description': None,
#      'pitch': {'battingPlayer': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'pitchingPlayer': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'throwingLeftOrRight': 'R',
#       'result': 'BALL',
#       'ballStartSpeed': 84,
#       'ballEndSpeed': 78,
#       'pitchedLocation': {'x': 111, 'y': 201}},
#      'playStatus': {'batter': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 3,
#       'strikeCount': 0,
#       'outCount': 2}},
#     {'description': None,
#      'pitch': {'battingPlayer': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'pitchingPlayer': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'throwingLeftOrRight': 'R',
#       'result': 'CALLED_STRIKE',
#       'ballStartSpeed': 91,
#       'ballEndSpeed': 83,
#       'pitchedLocation': {'x': 122, 'y': 175}},
#      'playStatus': {'batter': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 3,
#       'strikeCount': 1,
#       'outCount': 2}},
#     {'description': None,
#      'pitch': {'battingPlayer': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'pitchingPlayer': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'throwingLeftOrRight': 'R',
#       'result': 'FOUL',
#       'ballStartSpeed': 92,
#       'ballEndSpeed': 85,
#       'pitchedLocation': {'x': 145, 'y': 189}},
#      'playStatus': {'batter': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 3,
#       'strikeCount': 2,
#       'outCount': 2}},
#     {'description': None,
#      'pitch': {'battingPlayer': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'pitchingPlayer': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'throwingLeftOrRight': 'R',
#       'result': 'IN_PLAY_OUTS',
#       'ballStartSpeed': 93,
#       'ballEndSpeed': 86,
#       'pitchedLocation': {'x': 113, 'y': 187}},
#      'playStatus': {'batter': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 3,
#       'strikeCount': 2,
#       'outCount': 2}},
#     {'description': None,
#      'hit': {'battingPlayer': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'pitchingPlayer': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'hitType': 'GROUND_BALL',
#       'isOut': True,
#       'isCaughtOut': False,
#       'isError': False,
#       'retrievedByPlayer': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'retrievedAtLocation': {'x': 0, 'y': 0}},
#      'playStatus': {'batter': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 3,
#       'strikeCount': 2,
#       'outCount': 2}},
#     {'description': None,
#      'baseRunAttempt': {'runningPlayer': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'fromBase': 0,
#       'toBase': 1,
#       'isSafe': False,
#       'isRunScored': False,
#       'isForcedOut': True,
#       'isWalk': False,
#       'isWalkIntentional': False,
#       'isPassedBall': False,
#       'isWildPitch': False,
#       'isEarnedRun': False},
#      'playStatus': {'batter': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 3,
#       'strikeCount': 2,
#       'outCount': 3}},
#     {'description': None,
#      'ballThrow': {'fromPlayer': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'toPlayer': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'runningPlayer': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'fromBase': None,
#       'toBase': 1,
#       'thrownFromLocation': None,
#       'thrownToLocation': None,
#       'isCaught': True,
#       'isRunningPlayerOut': True,
#       'isTagOut': False,
#       'isForceOut': True,
#       'isThrowingError': False,
#       'isCatchingError': False},
#      'playStatus': {'batter': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 11456,
#        'firstName': 'Andrew',
#        'lastName': 'Cashner',
#        'position': 'P',
#        'jerseyNumber': 54},
#       'catcher': {'id': 10263,
#        'firstName': 'Caleb',
#        'lastName': 'Joseph',
#        'position': 'C',
#        'jerseyNumber': 36},
#       'firstBaseman': {'id': 10265,
#        'firstName': 'Chris',
#        'lastName': 'Davis',
#        'position': '1B',
#        'jerseyNumber': 19},
#       'secondBaseman': {'id': 10270,
#        'firstName': 'Jonathan',
#        'lastName': 'Schoop',
#        'position': '2B',
#        'jerseyNumber': 6},
#       'thirdBaseman': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'shortStop': {'id': 10268,
#        'firstName': 'Manny',
#        'lastName': 'Machado',
#        'position': 'SS',
#        'jerseyNumber': 13},
#       'leftFielder': {'id': 10269,
#        'firstName': 'Trey',
#        'lastName': 'Mancini',
#        'position': '1B',
#        'jerseyNumber': 67},
#       'centerFielder': {'id': 10272,
#        'firstName': 'Adam',
#        'lastName': 'Jones',
#        'position': 'CF',
#        'jerseyNumber': 10},
#       'rightFielder': {'id': 10274,
#        'firstName': 'Joey',
#        'lastName': 'Rickard',
#        'position': 'RF',
#        'jerseyNumber': 23},
#       'outFielder': None,
#       'ballCount': 3,
#       'strikeCount': 2,
#       'outCount': 3}}]},
#   {'inning': 1,
#    'inningHalf': 'BOTTOM',
#    'battingTeam': {'id': 111, 'abbreviation': 'BAL'},
#    'atBatPlay': [{'description': None,
#      'batterUp': {'battingPlayer': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'standingLeftOrRight': 'R',
#       'result': 'FLYOUT'},
#      'playStatus': {'batter': {'id': 10962,
#        'firstName': 'Tim',
#        'lastName': 'Beckham',
#        'position': '3B',
#        'jerseyNumber': 1},
#       'firstBaseRunner': None,
#       'secondBaseRunner': None,
#       'thirdBaseRunner': None,
#       'pitcher': {'id': 10722,
#        'firstName': 'Masahiro',
#        'lastName': 'Tanaka',
#        'position': 'P',
#        'jerseyNumber': 19},
#       'catcher': {'id': 10725,
#        'firstName': 'Austin',
#        'lastName': 'Romine',
#        'position': 'C',
#        'jerseyNumber': 27},
#       'firstBaseman': {'id': 10728,
#        'firstName': 'Gregory',
#        'lastName': 'Bird',
#        'position': '1B',
#        'jerseyNumber': None},
#       'secondBaseman': {'id': 11196,
#        'firstName': 'Neil',
#        'lastName': 'Walker',
#        'position': '2B',
#        'jerseyNumber': 14},
#       'thirdBaseman': {'id': 12233,
#        'firstName': 'Miguel',
#        'lastName': 'Andujar',
#        'position': '3B',
#        'jerseyNumber': 94},
#       'shortStop': {'id': 10730,
#        'firstName': 'Didi',
#        'lastName': 'Gregorius',
#        'position': 'SS',
#        'jerseyNumber': 18},
#       'leftFielder': {'id': 11091,
#        'firstName': 'Brett',
#        'lastName': 'Gardner',
#        'position': 'LF',
#        'jerseyNumber': 11},
#       'centerFielder': {'id': 11092,
#        'firstName': 'Aaron',
#        'lastName': 'Hicks',
#        'position': 'RF',
#        'jerseyNumber': 31},
#       'rightFielder': {'id': 10734,
#        'firstName': 'Aaron',
#        'lastName': 'Judge',
#        'position': 'RF',
#        'jerseyNumber': 99},
#       'outFielder': None,
# ...
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': 'Henry B. Plant, Tampa, FL',
#     'college': None,
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []},
#    {'id': 10263,
#     'firstName': 'Caleb',
#     'lastName': 'Joseph',
#     'primaryPosition': 'C',
#     'jerseyNumber': 36,
#     'currentTeam': {'id': 111, 'abbreviation': 'BAL'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'3"',
#     'weight': 180,
#     'birthDate': '1986-06-17',
#     'age': 32,
#     'birthCity': 'Nashville, TN',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': None,
#     'college': 'Lipscomb',
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []},
#    {'id': 10265,
#     'firstName': 'Chris',
#     'lastName': 'Davis',
#     'primaryPosition': '1B',
#     'jerseyNumber': 19,
#     'currentTeam': {'id': 111, 'abbreviation': 'BAL'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'3"',
#     'weight': 230,
#     'birthDate': '1986-03-16',
#     'age': 32,
#     'birthCity': 'Longview, TX',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': 'Longview High School',
#     'college': 'Navarro College',
#     'handedness': {'bats': None, 'throws': None},
#     'officialImageSrc': None,
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'CrushD19'}]},
#    {'id': 10268,
#     'firstName': 'Manny',
#     'lastName': 'Machado',
#     'primaryPosition': 'SS',
#     'jerseyNumber': 13,
#     'currentTeam': {'id': 137, 'abbreviation': 'LAD'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'3"',
#     'weight': 185,
#     'birthDate': '1992-07-05',
#     'age': 26,
#     'birthCity': 'Miami, FL',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': 'Brito Miami Private School, Miami, FL',
#     'college': None,
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []},
#    {'id': 10269,
#     'firstName': 'Trey',
#     'lastName': 'Mancini',
#     'primaryPosition': '1B',
#     'jerseyNumber': 67,
#     'currentTeam': {'id': 111, 'abbreviation': 'BAL'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'4"',
#     'weight': 215,
#     'birthDate': '1992-03-18',
#     'age': 26,
#     'birthCity': 'Winter Haven, FL',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': None,
#     'college': 'Notre Dame',
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []},
#    {'id': 10270,
#     'firstName': 'Jonathan',
#     'lastName': 'Schoop',
#     'primaryPosition': '2B',
#     'jerseyNumber': 6,
#     'currentTeam': {'id': 134, 'abbreviation': 'MIL'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'1"',
#     'weight': 225,
#     'birthDate': '1991-10-15',
#     'age': 27,
#     'birthCity': 'Willemstad',
#     'birthCountry': 'Curacao',
#     'rookie': False,
#     'highSchool': None,
#     'college': None,
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []},
#    {'id': 10272,
#     'firstName': 'Adam',
#     'lastName': 'Jones',
#     'primaryPosition': 'CF',
#     'jerseyNumber': 10,
#     'currentTeam': {'id': 111, 'abbreviation': 'BAL'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'2"',
#     'weight': 215,
#     'birthDate': '1985-08-01',
#     'age': 33,
#     'birthCity': 'San Diego, CA',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': 'Samuel Morse, San Diego, CA',
#     'college': None,
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'SimplyAJ10'}]},
#    {'id': 10274,
#     'firstName': 'Joey',
#     'lastName': 'Rickard',
#     'primaryPosition': 'RF',
#     'jerseyNumber': 23,
#     'currentTeam': {'id': 111, 'abbreviation': 'BAL'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'1"',
#     'weight': 185,
#     'birthDate': '1991-05-21',
#     'age': 27,
#     'birthCity': 'Las Vegas, NV',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': None,
#     'college': 'Arizona',
#     'handedness': {'bats': 'R', 'throws': 'L'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []},
#    {'id': 10275,
#     'firstName': 'Mark',
#     'lastName': 'Trumbo',
#     'primaryPosition': 'RF',
#     'jerseyNumber': 45,
#     'currentTeam': {'id': 111, 'abbreviation': 'BAL'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'4"',
#     'weight': 225,
#     'birthDate': '1986-01-16',
#     'age': 32,
#     'birthCity': 'Anaheim, CA',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': 'Villa Park, CA',
#     'college': None,
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'Mtrumbo44'}]},
#    {'id': 10392,
#     'firstName': 'Miguel',
#     'lastName': 'Castro',
#     'primaryPosition': 'P',
#     'jerseyNumber': 46,
#     'currentTeam': {'id': 111, 'abbreviation': 'BAL'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'7"',
#     'weight': 205,
#     'birthDate': '1994-12-24',
#     'age': 23,
#     'birthCity': 'La Romana',
#     'birthCountry': 'Dominican Republic',
#     'rookie': False,
#     'highSchool': None,
#     'college': None,
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []},
#    {'id': 10616,
#     'firstName': 'Giancarlo',
#     'lastName': 'Stanton',
#     'primaryPosition': 'RF',
#     'jerseyNumber': 27,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'6"',
#     'weight': 245,
#     'birthDate': '1989-11-07',
#     'age': 29,
#     'birthCity': 'Panorama, CA',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': 'Notre Dame, Sherman Oaks, CA',
#     'college': None,
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': [{'mediaType': 'TWITTER',
#       'value': 'Giancarlo818'}]},
#    {'id': 10713,
#     'firstName': 'Jonathan',
#     'lastName': 'Holder',
#     'primaryPosition': 'P',
#     'jerseyNumber': 65,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'2"',
#     'weight': 235,
#     'birthDate': '1993-06-09',
#     'age': 25,
#     'birthCity': 'Gulfport, MS',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': None,
#     'college': 'Mississippi State',
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'Jholder14'}]},
#    {'id': 10722,
#     'firstName': 'Masahiro',
#     'lastName': 'Tanaka',
#     'primaryPosition': 'P',
#     'jerseyNumber': 19,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'3"',
#     'weight': 215,
#     'birthDate': '1988-11-01',
#     'age': 30,
#     'birthCity': 'Itami',
#     'birthCountry': 'Japan',
#     'rookie': False,
#     'highSchool': 'Komazawa University Tomakomai High School, Hokkaido',
#     'college': None,
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': [{'mediaType': 'TWITTER',
#       'value': 't_masahiro18'}]},
#    {'id': 10725,
#     'firstName': 'Austin',
#     'lastName': 'Romine',
#     'primaryPosition': 'C',
#     'jerseyNumber': 27,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'1"',
#     'weight': 220,
#     'birthDate': '1988-11-22',
#     'age': 29,
#     'birthCity': 'Lake Forest, CA',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': 'El Toro, Lake Forest, CA',
#     'college': None,
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []},
#    {'id': 10728,
#     'firstName': 'Gregory',
#     'lastName': 'Bird',
#     'primaryPosition': '1B',
#     'jerseyNumber': None,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'4"',
#     'weight': 220,
#     'birthDate': '1992-11-09',
#     'age': 26,
#     'birthCity': 'Memphis, TN',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': 'Grandview, Aurora, CO',
#     'college': None,
#     'handedness': {'bats': 'L', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []},
#    {'id': 10730,
#     'firstName': 'Didi',
#     'lastName': 'Gregorius',
#     'primaryPosition': 'SS',
#     'jerseyNumber': 18,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'3"',
#     'weight': 205,
#     'birthDate': '1990-02-18',
#     'age': 28,
#     'birthCity': 'Amsterdam',
#     'birthCountry': 'Netherlands',
#     'rookie': False,
#     'highSchool': None,
#     'college': None,
#     'handedness': {'bats': 'L', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'DidiG18'}]},
#    {'id': 10734,
#     'firstName': 'Aaron',
#     'lastName': 'Judge',
#     'primaryPosition': 'RF',
#     'jerseyNumber': 99,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'7"',
#     'weight': 282,
#     'birthDate': '1992-04-26',
#     'age': 26,
#     'birthCity': 'Linden, CA',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': None,
#     'college': 'Fresno State',
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'TheJudge44'}]},
#    {'id': 10962,
#     'firstName': 'Tim',
#     'lastName': 'Beckham',
#     'primaryPosition': '3B',
#     'jerseyNumber': 1,
#     'currentTeam': {'id': 111, 'abbreviation': 'BAL'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'1"',
#     'weight': 205,
#     'birthDate': '1990-01-26',
#     'age': 28,
#     'birthCity': 'Griffin, GA',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': 'Griffin, GA',
#     'college': None,
#     'handedness': {'bats': None, 'throws': None},
#     'officialImageSrc': None,
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 't_beckham1'}]},
#    {'id': 11082,
#     'firstName': 'Dellin',
#     'lastName': 'Betances',
#     'primaryPosition': 'P',
#     'jerseyNumber': 68,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'8"',
#     'weight': 265,
#     'birthDate': '1988-03-23',
#     'age': 30,
#     'birthCity': 'New York, NY',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': 'Grand Street Campus, Brooklyn, NY',
#     'college': None,
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []},
#    {'id': 11085,
#     'firstName': 'Chad',
#     'lastName': 'Green',
#     'primaryPosition': 'P',
#     'jerseyNumber': None,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'3"',
#     'weight': 210,
#     'birthDate': '1991-05-24',
#     'age': 27,
#     'birthCity': 'Greenville, SC',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': None,
#     'college': 'Louisville',
#     'handedness': {'bats': 'L', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []},
#    {'id': 11091,
#     'firstName': 'Brett',
#     'lastName': 'Gardner',
#     'primaryPosition': 'LF',
#     'jerseyNumber': 11,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '5\'11"',
#     'weight': 195,
#     'birthDate': '1983-08-24',
#     'age': 35,
#     'birthCity': 'Holly Hill, SC',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': None,
#     'college': 'College of Charleston',
#     'handedness': {'bats': 'L', 'throws': 'L'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []},
#    {'id': 11092,
#     'firstName': 'Aaron',
#     'lastName': 'Hicks',
#     'primaryPosition': 'RF',
#     'jerseyNumber': 31,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'1"',
#     'weight': 202,
#     'birthDate': '1989-10-02',
#     'age': 29,
#     'birthCity': 'San Pedro, CA',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': 'Woodrow Wilson, Long Beach, CA',
#     'college': None,
#     'handedness': {'bats': 'S', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': [{'mediaType': 'TWITTER',
#       'value': 'AaronHicks31'}]},
#    {'id': 11123,
#     'firstName': 'David',
#     'lastName': 'Robertson',
#     'primaryPosition': 'P',
#     'jerseyNumber': 30,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '5\'11"',
#     'weight': 195,
#     'birthDate': '1985-04-09',
#     'age': 33,
#     'birthCity': 'Birmingham, AL',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': None,
#     'college': 'Alabama',
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': [{'mediaType': 'TWITTER', 'value': 'DRob30'}]},
#    {'id': 11196,
#     'firstName': 'Neil',
#     'lastName': 'Walker',
#     'primaryPosition': '2B',
#     'jerseyNumber': 14,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'3"',
#     'weight': 210,
#     'birthDate': '1985-09-09',
#     'age': 33,
#     'birthCity': 'Pittsburgh, PA',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': 'Pine-Richland, Gibsonia, PA',
#     'college': None,
#     'handedness': {'bats': None, 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': [{'mediaType': 'TWITTER',
#       'value': 'NeilWalker18'}]},
#    {'id': 11456,
#     'firstName': 'Andrew',
#     'lastName': 'Cashner',
#     'primaryPosition': 'P',
#     'jerseyNumber': 54,
#     'currentTeam': {'id': 111, 'abbreviation': 'BAL'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'6"',
#     'weight': 235,
#     'birthDate': '1986-09-10',
#     'age': 32,
#     'birthCity': 'Conroe, TX',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': None,
#     'college': 'Texas Christian',
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []},
#    {'id': 12233,
#     'firstName': 'Miguel',
#     'lastName': 'Andujar',
#     'primaryPosition': '3B',
#     'jerseyNumber': 94,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'0"',
#     'weight': 215,
#     'birthDate': '1995-03-02',
#     'age': 23,
#     'birthCity': 'San Cristobal',
#     'birthCountry': 'Dominican Republic',
#     'rookie': False,
#     'highSchool': None,
#     'college': None,
#     'handedness': {'bats': 'R', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []},
#    {'id': 12238,
#     'firstName': 'Tyler',
#     'lastName': 'Wade',
#     'primaryPosition': 'SS',
#     'jerseyNumber': 82,
#     'currentTeam': {'id': 114, 'abbreviation': 'NYY'},
#     'currentRosterStatus': 'ROSTER',
#     'currentInjury': None,
#     'height': '6\'1"',
#     'weight': 185,
#     'birthDate': '1994-11-23',
#     'age': 23,
#     'birthCity': 'Murrieta, CA',
#     'birthCountry': 'USA',
#     'rookie': False,
#     'highSchool': 'Murrieta Valley, Murrieta, CA',
#     'college': None,
#     'handedness': {'bats': 'L', 'throws': 'R'},
#     'officialImageSrc': None,
#     'socialMediaAccounts': []}]}}

# %%
with open( "c:/tmp/april.json.txt") as f :
    games =json.load(f)

# %%
for g in games["gamelogs"] :
    msfid = g['game']['id']
    if(g['game']['awayTeamAbbreviation']  == 'CHC') :
        print("{}: at {}".format( g['game']['startTime'][0:10], g['game']['homeTeamAbbreviation']))
    else :
        print("{}: {} at Wrigley".format(g['game']['startTime'][0:10], g['game']['awayTeamAbbreviation']))
# Out:
# 43469
# 2018-04-01: at MIA
# 43482
# 2018-04-02: at CIN
# 43528
# 2018-04-06: at MIL
# 43534
# 2018-04-07: at MIL
# 43544
# 2018-04-07: at MIL
# 43558
# 2018-04-08: at MIL
# 43568
# 2018-04-10: PIT at Wrigley
# 43608
# 2018-04-12: PIT at Wrigley
# 43610
# 2018-04-12: PIT at Wrigley
# 43618
# 2018-04-13: ATL at Wrigley
# 43638
# 2018-04-14: ATL at Wrigley
# 43684
# 2018-04-18: STL at Wrigley
# 43693
# 2018-04-19: STL at Wrigley
# 43722
# 2018-04-21: at COL
# 43737
# 2018-04-22: at COL
# 43752
# 2018-04-22: at COL
# 43767
# 2018-04-24: at CLE
# 43791
# 2018-04-25: at CLE
# 43804
# 2018-04-27: MIL at Wrigley
# 43806
# 2018-04-27: MIL at Wrigley
# 43822
# 2018-04-28: MIL at Wrigley
# 43847
# 2018-04-29: MIL at Wrigley
# 43857
# 2018-04-30: COL at Wrigley

# %%
for g in games["gamelogs"] :
    if(g['game']['awayTeamAbbreviation']  == 'CHC') :
# Out:
# k
# k
# k
# k
# k
# k
# k
# k
# k
# k
# k
