# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json

# %%
with open("c:/tmp/pbp.json", 'r') as f :
    game = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-e5130223fa52> in <module>()
# ----> 1 with open("c:/tmp/pbp.json", 'r') as f :
#       2     game = json.load(f)
#       3
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:/tmp/pbp.json'

# %%
game
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5905dd1afcfe> in <module>()
# ----> 1 game
#
# NameError: name 'game' is not defined

# %%
with open( "c:/tmp/april.json.txt") as f :
    games =json.load(f)

# %%
for g in games["gamelogs"] :
    msfid = g['game']['id']
    print (msfid)
    if(g['game']['awayTeamAbbreviation']  == 'CHC') :
        print("{}: at {}".format( g['game']['startTime'][0:10], g['game']['homeTeamAbbreviation']))
    else :
        print("{}: {} at Wrigley".format(g['game']['startTime'][0:10], g['game']['awayTeamAbbreviation']))
# Out:
# 43469
# 2018-04-01: at MIA
# 43482
# 2018-04-02: at CIN
# 43528
# 2018-04-06: at MIL
# 43534
# 2018-04-07: at MIL
# 43544
# 2018-04-07: at MIL
# 43558
# 2018-04-08: at MIL
# 43568
# 2018-04-10: PIT at Wrigley
# 43608
# 2018-04-12: PIT at Wrigley
# 43610
# 2018-04-12: PIT at Wrigley
# 43618
# 2018-04-13: ATL at Wrigley
# 43638
# 2018-04-14: ATL at Wrigley
# 43684
# 2018-04-18: STL at Wrigley
# 43693
# 2018-04-19: STL at Wrigley
# 43722
# 2018-04-21: at COL
# 43737
# 2018-04-22: at COL
# 43752
# 2018-04-22: at COL
# 43767
# 2018-04-24: at CLE
# 43791
# 2018-04-25: at CLE
# 43804
# 2018-04-27: MIL at Wrigley
# 43806
# 2018-04-27: MIL at Wrigley
# 43822
# 2018-04-28: MIL at Wrigley
# 43847
# 2018-04-29: MIL at Wrigley
# 43857
# 2018-04-30: COL at Wrigley

# %%
for g in games["gamelogs"] :
    if(g['game']['awayTeamAbbreviation']  == 'CHC') :
# Out:
#   File "<ipython-input-8-419f60bdd153>", line 3
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
games
# Out:
# {'lastUpdatedOn': '2018-11-13T16:58:17.730Z',
#  'gamelogs': [{'game': {'id': 43469,
#     'startTime': '2018-04-01T17:10:00.000Z',
#     'awayTeamAbbreviation': 'CHC',
#     'homeTeamAbbreviation': 'MIA'},
#    'team': {'id': 131, 'abbreviation': 'CHC'},
#    'stats': None},
#   {'game': {'id': 43482,
#     'startTime': '2018-04-02T20:10:00.000Z',
#     'awayTeamAbbreviation': 'CHC',
#     'homeTeamAbbreviation': 'CIN'},
#    'team': {'id': 131, 'abbreviation': 'CHC'},
#    'stats': None},
#   {'game': {'id': 43528,
#     'startTime': '2018-04-06T00:10:00.000Z',
#     'awayTeamAbbreviation': 'CHC',
#     'homeTeamAbbreviation': 'MIL'},
#    'team': {'id': 131, 'abbreviation': 'CHC'},
#    'stats': None},
#   {'game': {'id': 43534,
#     'startTime': '2018-04-07T00:10:00.000Z',
#     'awayTeamAbbreviation': 'CHC',
#     'homeTeamAbbreviation': 'MIL'},
#    'team': {'id': 131, 'abbreviation': 'CHC'},
#    'stats': None},
#   {'game': {'id': 43544,
# ...

# %%
import io
import requests
import base64

token_file ='msf_token.txt'
token_directory = '/api/'


def get_msf_token() :
    with open(token_directory + token_file) as tfile :
        token = tfile.read()
    return  token.strip()



# https://api.mysportsfeeds.com/v2.0/pull/mlb/{season}/games/{game}/playbyplay.{format}

def play_by_play_json(season, game) :
    pullurl = "https://api.mysportsfeeds.com/v2.0/pull/mlb/{}/games/{}/playbyplay.json".format(season, game)
    
    token = get_msf_token()

    pullheaders={
        "Authorization": "Basic " + base64.b64encode('{}:{}'.format(token,'MYSPORTSFEEDS').encode('utf-8')).decode('ascii')
        }
    print( pullheaders )
    print("---------")
    
    try:
        r = requests.get(
            url = pullurl,
            params = {},
            headers = pullheaders
            )
        print('Response HTTP Status Code: {status_code}'.format(status_code=r.status_code))
        return r.content    
    except requests.exceptions.RequestException:
        print('HTTP Request failed')
            


def pbp_to_json_file(game_id, file_name) :
    pbp = play_by_play_json('2018-regular', game_id)
    with open (file_name, "wb") as f :
        f.write(pbp)
            
# pbp = play_by_play_json('2018-regular', '44792')

json_file = "/tmp/pbpx.json"

pbp_to_json_file('43806', json_file)
# Out:
# {'Authorization': 'Basic MTNkYTFiMDgtZTdiNi00ZjcxLTg4OWEtODJhM2M5Ok1ZU1BPUlRTRkVFRFM='}
# ---------
# Response HTTP Status Code: 200

# %%
get_msf_token()
# Out:
# '13da1b08-e7b6-4f71-889a-82a3c9'

# %%
import json
with open(json_file,"r") as f:
     pbp = json.load(f)

# %%
pbp
# Out:
# {'lastUpdatedOn': '2018-11-19T16:09:57.096Z',
#  'game': {'id': 43806,
#   'startTime': '2018-04-27T18:20:00.000Z',
#   'endedTime': None,
#   'awayTeam': {'id': 134, 'abbreviation': 'MIL'},
#   'homeTeam': {'id': 131, 'abbreviation': 'CHC'},
#   'venue': {'id': 133, 'name': 'Wrigley Field'},
#   'venueAllegiance': 'HOME',
#   'scheduleStatus': 'NORMAL',
#   'originalStartTime': None,
#   'delayedOrPostponedReason': None,
#   'playedStatus': 'COMPLETED',
#   'attendance': None,
#   'officials': [],
#   'broadcasters': [],
#   'weather': None},
#  'atBats': [{'inning': 1,
#    'inningHalf': 'TOP',
#    'battingTeam': {'id': 134, 'abbreviation': 'MIL'},
#    'atBatPlay': [{'description': None,
#      'batterUp': {'battingPlayer': {'id': 10532,
#        'firstName': 'Lorenzo',
#        'lastName': 'Cain',
#        'position': 'CF',
#        'jerseyNumber': 6},
#       'standingLeftOrRight': 'R',
#       'result': 'DOUBLE'},
#      'playStatus': {'batter': {'id': 10532,
# ...

# %%
for b in pbp['atBats'] :
    print("Next play")
    i=0
    for p in b['atBatPlay'] :
        print ("next p")
        if ("playStatus" not in p.keys ()):
            print ("HELL NO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
        if('batterUp' in p.keys()) :
            pl = p['batterUp']['battingPlayer']
            print ("{} {} {}".format(pl['firstName'], pl['lastName'], p['batterUp']['result']))
        else:
            i +=1
# Out:
# Next play
# next p
# Lorenzo Cain DOUBLE
# next p
# next p
# next p
# Next play
# next p
# Christian Yelich STRIKEOUT
# next p
# next p
# next p
# next p
# next p
# Next play
# next p
# Jesus Aguilar SACRIFICE_FLY
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# Next play
# next p
# Travis Shaw STRIKEOUT
# next p
# next p
# next p
# next p
# next p
# next p
# Next play
# next p
# Albert Almora Jr. DOUBLE
# next p
# next p
# next p
# next p
# next p
# Next play
# next p
# Javier Baez SINGLE
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# Next play
# next p
# Anthony Rizzo SINGLE
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# Next play
# next p
# Willson Contreras FLYOUT
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# Next play
# next p
# David Bote GROUNDOUT
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# next p
# ...

# %%
drubs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f6cb1c0c071a> in <module>()
# ----> 1 drubs
#
# NameError: name 'drubs' is not defined

# %%
SyntaxError: invalid syntax

# %%
for b in pbp['atBats'] :
    for p in b['atBatPlay'] :
       
        if ("playStatus" not in p.keys ()):
            print ("HELL NO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")

# %%
  print ("HELL NO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
# Out:
# HELL NO!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
for b in pbp['atBats'] :
    print("Next atbat")
    i=0
    for p in b['atBatPlay'] :
        plstatus=p["playStatus"]
        print (plstatus['ballCount']+ "a")
        if p['playStatus']['firstBaseRunner'] != None :
            print ("next atbatplay First")
        if p['playStatus']['secondBaseRunner'] != None :
            print ("next atbatplay Second")
        if p['playStatus']['thirdBaseRunner'] != None :
            print ("next atbatplay Third")
        if('batterUp' in p.keys()):
            pl = p['batterUp']['battingPlayer']
            
            print ("{} {} {} {}".format(pl['firstName'], pl['lastName'], p['batterUp']['result'], plstatus['ballCount']))
        else:
            i +=1
# Out:
# Next atbat
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-3776ae6f1bed> in <module>()
#       6     for p in b['atBatPlay'] :
#       7         plstatus=p["playStatus"]
# ----> 8         print (plstatus['ballCount']+ "a")
#       9         if p['playStatus']['firstBaseRunner'] != None :
#      10             print ("next atbatplay First")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
with open("c:/tmp/dump.txt", "w") as f:
    f.write(json.dumps(pbp, indent=4))

# %%
plstatus=p["playStatus"]
